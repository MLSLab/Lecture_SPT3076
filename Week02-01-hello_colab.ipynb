# %%
2+3
# Out:
# 5

# %%
import socket
print(socket.gethostname())
# Out:
# bb808b1fd5a0

# %%
import platform

# %%
platform.platform()
# Out:
# 'Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic'

# %%
import numpy as np

# %%
np.eye(3, 3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.eye(2, 2)
# Out:
# array([[1., 0.],
#        [0., 1.]])
