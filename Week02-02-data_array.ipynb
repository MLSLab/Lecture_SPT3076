# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris() # 데이터 로드

# %%
x = iris.data

# %%
x.shape
# Out:
# (150, 4)

# %%
x[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
x[0, :]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
x[0, 2]
# Out:
# 1.4

# %%
x[-1] # 맨 마지막 instance
# Out:
# array([5.9, 3. , 5.1, 1.8])

# %%
x[-2] # 끝에서 두번째 instance
# Out:
# array([6.2, 3.4, 5.4, 2.3])

# %%
x[-5:] # 끝에서 다섯번째부터
# Out:
# array([[6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
import numpy as np
x1 = np.array([[5.1], [3.5], [1.4], [0.2]])

# %%
x1.shape
# Out:
# (4, 1)

# %%
x2 = np.array([5.1, 3.5, 1.4, 0.2])

# %%
x2.shape
# Out:
# (4,)

# %% [markdown]
# iris 꽃 데이터

# %%
x[1]
# Out:
# array([4.9, 3. , 1.4, 0.2])

# %%
x[1].shape
# Out:
# (4,)

# %%
iris_two = x[3:5]

# %%
iris_two
# Out:
# array([[4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
iris_two.shape
# Out:
# (2, 4)

# %%
iris_two.T
# Out:
# array([[4.6, 5. ],
#        [3.1, 3.6],
#        [1.5, 1.4],
#        [0.2, 0.2]])

# %%
iris_two.T.T
# Out:
# array([[4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
iris_two.T.shape
# Out:
# (4, 2)

# %% [markdown]
# 특수한 벡터와 행렬

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.zeros((5,1))
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
np.ones((1,5))
# Out:
# array([[1., 1., 1., 1., 1.]])

# %% [markdown]
# Tensor

# %%
from scipy import misc

# %%
img_rgb = misc.face()

# %%
img_rgb.shape
# Out:
# (768, 1024, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img_rgb)

# %%
# Green
plt.imshow(img_rgb[:, :, 1], cmap=plt.cm.gray)

# %%
# Red
plt.imshow(img_rgb[:, :, 0], cmap=plt.cm.gray)  # first channel
plt.title('Red channel')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Red channel')
