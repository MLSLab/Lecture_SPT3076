# %% [markdown]
# Hello Python Dictionary !

# %%
phones = {}

# %%
phones['pat'] = '6918'

# %%
phones
# Out:
# {'pat': '6918'}

# %%
phones['Pat'] = '6918'

# %%
phones
# Out:
# {'Pat': '6918', 'pat': '6918'}

# %%
phones.pop('pat')
# Out:
# '6918'

# %%
phones
# Out:
# {'Pat': '6918'}

# %%
phones['Juliette'] = 6917

# %%
phones
# Out:
# {'Juliette': 6917, 'Pat': '6918'}

# %%
phones['Pat'] = 6918

# %%
phones
# Out:
# {'Juliette': 6917, 'Pat': 6918}

# %%
phones['Mehran'] = 6916

# %%
phones
# Out:
# {'Juliette': 6917, 'Mehran': 6916, 'Pat': 6918}

# %%
phones['Seung']= 6918

# %%
phones
# Out:
# {'Juliette': 6917, 'Mehran': 6916, 'Pat': 6918, 'Seung': 6918}

# %%
phones.keys()
# Out:
# dict_keys(['Pat', 'Juliette', 'Mehran', 'Seung'])

# %%
for key in phones.keys():
  print(key)
# Out:
# Pat
# Juliette
# Mehran
# Seung

# %%
phones.values()
# Out:
# dict_values([6918, 6917, 6916, 6918])

# %%
len(phones.values())
# Out:
# 4

# %%
len(phones)
# Out:
# 4
