# %% [markdown]
# # K-최근접이웃 (K-Nearest Neighbor, KNN) 알고리즘

# %% [markdown]
# 전반전까지의 결과를 이용하여 승리를 예측해보는 kNN 모델. 학습을 위해 단순하게 구성이 되었음

# %% [markdown]
# ### Data 준비

# %%
blocks = [2, 1, 3, 3, 2]
lead_at_half = [3, 4, 2, 3, 2]
#pass_success = [5, 6, 7, 3, 9]

# %%
win = [1, 0, 1, 0, 1] # Target, 라벨, label

# %%
#combinig weather and temp into single listof tuples
features=list(zip(blocks, lead_at_half)) #특징

# %%
features
# Out:
# [(2, 3), (1, 4), (3, 2), (3, 3), (2, 2)]

# %% [markdown]
# ### Classifier 준비 및 학습하기

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3) #k=3 설정

# %% [markdown]
# * 데이터를 이용하여 학습하기

# %%
# Train the model using the training sets
model.fit(features,win)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### 예측해보기
# 어떻게 될 것인가?

# %%
model.predict([(3, 1)])
# Out:
# array([1])

# %%
model.predict([(3, 4)])
# Out:
# array([1])

# %%
model.predict([(2, 5)])
# Out:
# array([0])

# %% [markdown]
# ### References
# https://medium.com/kenyon-college-sports-analytics/using-knn-methods-to-predict-cavs-outcomes-based-on-halftime-data-b809b2d47ae6
