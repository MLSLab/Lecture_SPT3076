# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jooeungen/coronaboard_kr/master/kr_daily.csv', parse_dates=['date'], index_col="date")

# %%
df
# Out:
#             confirmed  death  released    tested  negative  critical
# date
# 2020-01-21          1      0         0         1         0       NaN
# 2020-01-22          1      0         0         1         0       NaN
# 2020-01-23          1      0         0         1         0       NaN
# 2020-01-24          2      0         0         2         0       NaN
# 2020-01-25          2      0         0         2         0       NaN
# ...               ...    ...       ...       ...       ...       ...
# 2022-02-24    2499178   7689    969524  17938543  14052403     581.0
# 2022-02-25    2665068   7783    969524  18104433  14052403     655.0
# 2022-02-26    2831275   7895    969524  18270640  14052403     643.0
# 2022-02-27    2994830   7944    969524  18434195  14052403     663.0
# 2022-02-28    3134456   8058    969524  18573821  14052403     715.0
#
# [770 rows x 6 columns]
